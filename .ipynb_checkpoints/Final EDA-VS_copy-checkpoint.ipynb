# %%
# SUP GUYS IT'S YA GIRL LET'S DO THIS SHIT
# here I am importing things 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from mpl_toolkits.basemap import Basemap  #Tom  doesn't have this. How do you install it?

# %matplotlib inline

# %%
test = pd.read_csv('./assets/test.csv')
train = pd.read_csv('./assets/train.csv')
spray = pd.read_csv('./assets/spray.csv')
weather = pd.read_csv('./assets/weather.csv')

# %%
# checking out the first five rows of the test data

test.head()
# Out:
#    Id        Date                                            Address  \
# 0   1  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1   2  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2   3  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 3   4  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 4   5  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2           CULEX PIPIENS     41   N OAK PARK AVE  T002
# 3        CULEX SALINARIUS     41   N OAK PARK AVE  T002
# 4         CULEX TERRITANS     41   N OAK PARK AVE  T002
#
#               AddressNumberAndStreet  Latitude  Longitude  AddressAccuracy
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 2  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 3  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 4  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9

# %%
train.head()
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
# 3    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 4    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
#
#    NumMosquitos  WnvPresent
# 0             1           0
# 1             1           0
# 2             1           0
# 3             1           0
# 4             4           0

# %% [markdown]
# ## Doing some initial analysis and cleaning on 'train' and 'test'

# %%
# dropping the additional index column 

test.drop(columns = 'Id', inplace = True)

# %%
# changing the 'Date' column to a datetime

train['Date'] = pd.to_datetime(train['Date'])
test['Date'] = pd.to_datetime(test['Date'])

# %%
# changing the date to the index

train = train.set_index('Date')
test = test.set_index('Date')

# %%
# confirming it worked
print(type(train.index[0]))
train.head()
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
#                                                       Address  \
# Date
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                            Species  Block           Street  Trap  \
# Date
# 2007-05-29  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 2007-05-29          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2007-05-29          CULEX RESTUANS     62    N MANDELL AVE  T007
# 2007-05-29  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 2007-05-29          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#                        AddressNumberAndStreet   Latitude  Longitude  \
# Date
# 2007-05-29  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2007-05-29  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2007-05-29   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 2007-05-29    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 2007-05-29    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
#
#             AddressAccuracy  NumMosquitos  WnvPresent
# Date
# 2007-05-29                9             1           0
# 2007-05-29                9             1           0
# 2007-05-29                9             1           0
# 2007-05-29                8             1           0
# 2007-05-29                8             4           0

# %%
# wanted to see how the counts of mosquitos and the infected mosquito counts
# related

train.sort_values('WnvPresent', ascending = False).head(20)
# Out:
#                                                       Address  \
# Date
# 2007-09-05     2200 West 113th Street, Chicago, IL 60643, USA
# 2011-08-12            Ohare Court, Bensenville, IL 60106, USA
# 2013-08-22    3700 South Pulaski Road, Chicago, IL 60623, USA
# 2013-08-22    5000 South Union Avenue, Chicago, IL 60609, USA
# 2007-08-21  5200 South Nordica Avenue, Chicago, IL 60638, USA
# 2013-08-22   6700 South Kedzie Avenue, Chicago, IL 60629, USA
# 2013-08-22   6700 South Kedzie Avenue, Chicago, IL 60629, USA
# 2007-08-21  5200 South Nordica Avenue, Chicago, IL 60638, USA
# 2011-08-12  5100 North Mont Clare Avenue, Chicago, IL 6065...
# 2013-08-22      2200 West 51st Street, Chicago, IL 60609, USA
# 2007-08-21  Chicago Midway International Airport (MDW), 52...
# 2007-08-21  Chicago Midway International Airport (MDW), 52...
# 2011-08-12            Ohare Court, Bensenville, IL 60106, USA
# 2013-08-22  2500 South Millard Avenue, Chicago, IL 60623, USA
# 2013-08-22  1000 North Central Park Avenue, Chicago, IL 60...
# 2011-08-12  ORD Terminal 5, O'Hare International Airport, ...
# 2013-08-22  1100 South California Avenue, Chicago, IL 6061...
# 2007-08-21      2200 West 51st Street, Chicago, IL 60609, USA
# 2013-08-22   6100 North Lemont Avenue, Chicago, IL 60646, USA
1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 2013-08-22       1100  S CALIFORNIA, Chicago, IL  41.868142 -87.696269
# 2007-08-21          2200  W 51ST ST, Chicago, IL  41.801179 -87.679447
# 2013-08-22       6100  N LEMONT AVE, Chicago, IL  41.991429 -87.747113
# 2007-08-21          2200  W 51ST ST, Chicago, IL  41.801179 -87.679447
#
#             AddressAccuracy  NumMosquitos  WnvPresent
# Date
# 2007-09-05                8            13           1
# 2011-08-12                5             8           1
# 2013-08-22                9             6           1
# 2013-08-22                8            15           1
# 2007-08-21                8            10           1
# 2013-08-22                8            14           1
# 2013-08-22                8             4           1
# 2007-08-21                8            13           1
# 2011-08-12                9             3           1
# 2013-08-22                8             1           1
# 2007-08-21                9            40           1
# 2007-08-21                9            27           1
# 2011-08-12                5            50           1
# 2013-08-22                9             3           1
# 2013-08-22                9            47           1
# 2011-08-12                9            11           1
# 2013-08-22                9            13           1
# 2007-08-21                8            18           1
# 2013-08-22                8             5           1
# 2007-08-21                8            13           1

# %%
# created an additional column that shows the percentage of infected mosquitos

train['PercentageWnv'] = train['WnvPresent'] / train['NumMosquitos']

# %%
# make sure it works
train['PercentageWnv'].value_counts()
# Out:
# 0.000000    9955
# 0.020000     108
# 1.000000      20
# 0.076923      20
# 0.200000      19
# 0.111111      17
# 0.062500      15
# 0.333333      15
# 0.142857      13
# 0.047619      12
# 0.250000      12
# 0.083333      12
# 0.025641      11
# 0.100000      11
# 0.027027      11
# 0.066667      11
# 0.032258      11
# 0.125000      11
# 0.055556      11
# 0.037037      10
# 0.166667      10
# 0.043478      10
# 0.058824       9
# 0.050000       9
# 0.090909       8
# 0.041667       8
# 0.071429       8
# 0.035714       8
# 0.027778       8
# 0.026316       8
# 0.020833       8
# 0.500000       7
# 0.030303       7
# 0.033333       7
# 0.045455       6
# 0.023256       6
# 0.021277       6
# 0.052632       6
# 0.038462       6
# 0.034483       6
# 0.022222       5
# 0.024390       5
# 0.020408       5
# 0.021739       5
# 0.040000       5
# 0.023810       5
# 0.025000       5
# 0.028571       5
# 0.031250       4
# 0.029412       3
# 0.022727       3
# Name: PercentageWnv, dtype: int64

# %%
train.head()
# Out:
#                                                       Address  \
# Date
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                            Species  Block           Street  Trap  \
# Date
# 2007-05-29  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 2007-05-29          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2007-05-29          CULEX RESTUANS     62    N MANDELL AVE  T007
# 2007-05-29  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 2007-05-29          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#                        AddressNumberAndStreet   Latitude  Longitude  \
# Date
# 2007-05-29  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2007-05-29  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2007-05-29   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 2007-05-29    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 2007-05-29    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
#
#             AddressAccuracy  NumMosquitos  WnvPresent  PercentageWnv
# Date
# 2007-05-29                9             1           0            0.0
# 2007-05-29                9             1           0            0.0
# 2007-05-29                9             1           0            0.0
# 2007-05-29                8             1           0            0.0
# 2007-05-29                8             4           0            0.0

# %% [markdown]
# ### Now to the "Spray" data

# %%
spray.head()
# Out:
#          Date        Time   Latitude  Longitude
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858

# %%
spray.isnull().sum()
# Out:
# Date           0
# Time         584
# Latitude       0
# Longitude      0
# dtype: int64

# %%
# decided to put the most common time in the null time values

spray['Time'].value_counts()
# Out:
# 7:44:32 PM     541
# 8:55:26 PM       5
# 8:55:46 PM       5
# 8:55:36 PM       5
# 8:58:56 PM       5
# 8:57:46 PM       5
# 9:31:27 PM       5
# 8:57:56 PM       5
# 9:37:27 PM       5
# 9:05:56 PM       5
# 9:40:27 PM       5
# 8:58:26 PM       5
# 9:35:47 PM       5
# 8:59:06 PM       5
# 9:38:27 PM       5
# 9:16:26 PM       4
# 8:31:11 PM       4
# 9:38:17 PM       4
# 9:30:27 PM       4
# 9:08:56 PM       4
# 8:41:55 PM       4
# 8:31:26 PM       4
# 8:48:25 PM       4
# 9:21:46 PM       4
# 8:55:25 PM       4
# 8:31:36 PM       4
# 9:27:05 PM       4
# 9:19:15 PM       4
# 9:04:46 PM       4
# 9:16:05 PM       4
#               ...
# 10:40:16 PM      1
# 10:20:59 PM      1
# 9:19:38 PM       1
# 9:17:03 PM       1
# 7:56:46 PM       1
# 11:14:28 PM      1
# 8:45:26 PM       1
# 10:44:31 PM      1
# 8:44:00 PM       1
# 9:05:00 PM       1
# 9:05:42 PM       1
# 11:06:50 PM      1
# 10:25:09 PM      1
# 9:02:00 PM       1
# 10:17:33 PM      1
# 11:01:06 PM      1
# 7:51:46 PM       1
# 11:53:38 PM      1
# 9:17:21 PM       1
# 10:18:33 PM      1
# 7:48:16 PM       1
# 8:44:02 PM       1
# 9:36:56 PM       1
# 8:05:43 PM       1
# 8:39:11 PM       1
# 10:15:26 PM      1
# 11:16:08 PM      1
# 11:57:41 PM      1
# 9:43:11 PM       1
# 7:54:06 PM       1
# Name: Time, Length: 8583, dtype: int64

# %%
# fill in na values with the most common time

spray['Time'].fillna('7:44:32 PM', inplace = True)

# %%
# combine date and time columns 

spray['DateTime'] = spray['Date'] + ' ' + spray['Time']

# %%
# convert to datetime and convert to index

spray['DateTime'] = pd.to_datetime(spray['DateTime'])
spray = spray.set_index('DateTime')

# %%
# drop date and time columns as they are redundant 

spray.drop(columns = ['Date', 'Time'], inplace = True)

# %%
# check to make sure it worked

spray.head()
# Out:
#                       Latitude  Longitude
# DateTime
# 2011-08-29 18:56:58  42.391623 -88.089163
# 2011-08-29 18:57:08  42.391348 -88.089163
# 2011-08-29 18:57:18  42.391022 -88.089157
# 2011-08-29 18:57:28  42.390637 -88.089158
# 2011-08-29 18:57:38  42.390410 -88.088858

# %%
# THIS IS A TEST AND IS NOT GOOD, TK WAS WORKING ON BASEMAP AS WELL. LEAVING THIS IN INCASE ANYONE
# WANTS TO WORK ON IT

# plt.figure(figsize=(8, 8))
# earth = Basemap(projection = 'merc',
#                 lon_0 = -87.6298,
#                 lat_0 = 41.8781,
#                 llcrnrlon=-85, 
#                 llcrnrlat=39,
#                 urcrnrlon=-89, 
#                 urcrnrlat=45,
#                 resolution = 'h'
#                )
# earth.bluemarble(alpha=0.42)
# earth.drawcoastlines(color='grey', linewidth=1)
# #earth.drawcounties(color = 'grey', linewidth=1)
# plt.scatter(spray['Longitude'], spray['Latitude'], 
#             c='red',alpha=.5)
# #plt.figsize()
# plt.xlabel("Test");

# %% [markdown]
# ### moving to 'Weather' data

# %%
weather.head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
#
#      ...    CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 0    ...                0      M      0.0        0.00       29.10    29.82
# 1    ...                M      M        M        0.00       29.18    29.82
# 2    ...         BR     0      M      0.0        0.00       29.38    30.09
# 3    ...      BR HZ     M      M        M        0.00       29.44    30.08
# 4    ...                0      M      0.0        0.00       29.39    30.12
#
#   ResultSpeed ResultDir  AvgSpeed
# 0         1.7        27       9.2
# 1         2.7        25       9.6
# 2        13.0         4      13.4
# 3        13.3         2      13.4
# 4        11.7         7      11.9
#
# [5 rows x 22 columns]

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 22 columns):
# Station        2944 non-null int64
# Date           2944 non-null object
# Tmax           2944 non-null int64
# Tmin           2944 non-null int64
# Tavg           2944 non-null object
# Depart         2944 non-null object
# DewPoint       2944 non-null int64
# WetBulb        2944 non-null object
# Heat           2944 non-null object
# Cool           2944 non-null object
# Sunrise        2944 non-null object
# Sunset         2944 non-null object
# CodeSum        2944 non-null object
# Depth          2944 non-null object
# Water1         2944 non-null object
# SnowFall       2944 non-null object
# PrecipTotal    2944 non-null object
# StnPressure    2944 non-null object
# SeaLevel       2944 non-null object
# ResultSpeed    2944 non-null float64
# ResultDir      2944 non-null int64
# AvgSpeed       2944 non-null object
# dtypes: float64(1), int64(5), object(16)
# memory usage: 506.1+ KB

# %%
# converting date to datetime

weather['Date'] = pd.to_datetime(weather['Date'])

# %%
# setting date to index

weather = weather.set_index('Date')

# %%
# station 2 sucks at recording things, it has a lot more missing data.

weather.head()
# Out:
#             Station  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# Date
# 2007-05-01        1    83    50   67     14        51      56    0    2
# 2007-05-01        2    84    52   68      M        51      57    0    3
# 2007-05-02        1    59    42   51     -3        42      47   14    0
# 2007-05-02        2    60    43   52      M        42      47   13    0
# 2007-05-03        1    66    46   56      2        40      48    9    0
#
#            Sunrise    ...    CodeSum Depth Water1 SnowFall PrecipTotal  \
# Date                  ...
# 2007-05-01    0448    ...                0      M      0.0        0.00
# 2007-05-01       -    ...                M      M        M        0.00
# 2007-05-02    0447    ...         BR     0      M      0.0        0.00
# 2007-05-02       -    ...      BR HZ     M      M        M        0.00
# 2007-05-03    0446    ...                0      M      0.0        0.00
#
#            StnPressure SeaLevel ResultSpeed  ResultDir  AvgSpeed
# Date
# 2007-05-01       29.10    29.82         1.7         27       9.2
# 2007-05-01       29.18    29.82         2.7         25       9.6
# 2007-05-02       29.38    30.09        13.0          4      13.4
# 2007-05-02       29.44    30.08        13.3          2      13.4
# 2007-05-03       29.39    30.12        11.7          7      11.9
#
# [5 rows x 21 columns]

# %%
# here we will replace 'M' with nan values (as it is missing) and change 'T' to a small decimal (as it stands for trace)
# as it was recorded as 'trace'

weather.replace('M', np.nan, inplace = True)
weather.replace('  T', 0.005, inplace = True) #This was annoying

# %%
weather.head(10) # Checking to make sure it worked. There are a few NANs and .005s in there.
# Out:
#             Station  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# Date
# 2007-05-01        1    83    50   67     14        51      56    0    2
# 2007-05-01        2    84    52   68    NaN        51      57    0    3
# 2007-05-02        1    59    42   51     -3        42      47   14    0
# 2007-05-02        2    60    43   52    NaN        42      47   13    0
# 2007-05-03        1    66    46   56      2        40      48    9    0
# 2007-05-03        2    67    48   58    NaN        40      50    7    0
# 2007-05-04        1    66    49   58      4        41      50    7    0
# 2007-05-04        2    78    51  NaN    NaN        42      50  NaN  NaN
# 2007-05-05        1    66    53   60      5        38      49    5    0
# 2007-05-05        2    66    54   60    NaN        39      50    5    0
#
#            Sunrise    ...    CodeSum Depth Water1  SnowFall PrecipTotal  \
# Date                  ...
# 2007-05-01    0448    ...                0    NaN       0.0        0.00
# 2007-05-01       -    ...              NaN    NaN       NaN        0.00
# 2007-05-02    0447    ...         BR     0    NaN       0.0        0.00
# 2007-05-02       -    ...      BR HZ   NaN    NaN       NaN        0.00
# 2007-05-03    0446    ...                0    NaN       0.0        0.00
# 2007-05-03       -    ...         HZ   NaN    NaN       NaN        0.00
# 2007-05-04    0444    ...         RA     0    NaN       0.0       0.005
# 2007-05-04       -    ...              NaN    NaN       NaN        0.00
# 2007-05-05    0443    ...                0    NaN       0.0       0.005
# 2007-05-05       -    ...              NaN    NaN       NaN       0.005
#
#            StnPressure SeaLevel ResultSpeed  ResultDir  AvgSpeed
# Date
# 2007-05-01       29.10    29.82         1.7         27       9.2
# 2007-05-01       29.18    29.82         2.7         25       9.6
# 2007-05-02       29.38    30.09        13.0          4      13.4
# 2007-05-02       29.44    30.08        13.3          2      13.4
# 2007-05-03       29.39    30.12        11.7          7      11.9
# 2007-05-03       29.46    30.12        12.9          6      13.2
# 2007-05-04       29.31    30.05        10.4          8      10.8
# 2007-05-04       29.36    30.04        10.1          7      10.4
# 2007-05-05       29.40    30.10        11.7          7      12.0
# 2007-05-05       29.46    30.09        11.2          7      11.5
#
# [10 rows x 21 columns]

# %%
weather.isnull().sum()
# Out:
# Station           0
# Tmax              0
# Tmin              0
# Tavg             11
# Depart         1472
# DewPoint          0
# WetBulb           4
# Heat             11
# Cool             11
# Sunrise           0
# Sunset            0
# CodeSum           0
# Depth          1472
# Water1         2944
# SnowFall       1472
# PrecipTotal       2
# StnPressure       4
# SeaLevel          9
# ResultSpeed       0
# ResultDir         0
# AvgSpeed          3
# dtype: int64

# %%
# deleting the columns that give little to no information

weather.drop(columns = ['Water1', 'Depth', 'SnowFall', 'Depart', 'CodeSum'], inplace = True)

# %%
# here we are filling in the missing 'Tavg' data with the average 

weather['Tavg'].fillna(((weather['Tmax'] + weather['Tmin']) / 2), inplace = True)

# %%
# making the columns with null values easier to read
# What null columns are left to deal with

null_columns = weather.columns[weather.isnull().any()]
weather[null_columns].isnull().sum()
# Out:
# WetBulb         4
# Heat           11
# Cool           11
# PrecipTotal     2
# StnPressure     4
# SeaLevel        9
# AvgSpeed        3
# dtype: int64

# %%
print('Null Rows: ', weather[weather.isnull().any(axis=1)][null_columns].shape[0])
print('Total Rows: ', weather.shape[0])
#Tom G thinks we should just drop these
# Out:
# Null Rows:  26
# Total Rows:  2944

# %%
#Being overly cautious before dropping data
weather.dropna().shape
# Out:
# (2918, 16)

# %%
weather.dropna(inplace=True)

# %%
weather.drop(columns = ['Heat', 'Cool'], inplace = True)

# %%
weather.head(2)
# Out:
#             Station  Tmax  Tmin Tavg  DewPoint WetBulb Sunrise Sunset  \
# Date
# 2007-05-01        1    83    50   67        51      56    0448   1849
# 2007-05-01        2    84    52   68        51      57       -      -
#
#            PrecipTotal StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# Date
# 2007-05-01        0.00       29.10    29.82          1.7         27      9.2
# 2007-05-01        0.00       29.18    29.82          2.7         25      9.6

# %% [markdown]
# ## Set the '-' from weather station 2 to the times from weather station 1

# %%
print(weather[weather['Station']==1].shape[0])
print(weather[weather['Station']==2].shape[0]) #This is annoying. I was hoping that there would be the same amount in both so I could change the sunrise/sunset for station 2 easier.
# Out:
# 1464
# 1454

# %%
# There is definitely a prettier way of doing this. 
# Filling in t
for i in range(weather.shape[0]-1):
    if weather.index[i] == weather.index[i+1]:
        if weather.iloc[i, 0] == 1: #Station 1
            if weather.iloc[i+1, 0] == 2: #Station 2
                weather.iloc[i+1, 8:10] = weather.iloc[i, 8:10]

# %%
weather.head(6) #checking to make sure that they worked correctly
# Out:
#             Station  Tmax  Tmin Tavg  DewPoint WetBulb Sunrise Sunset  \
# Date
# 2007-05-01        1    83    50   67        51      56    0448   1849
# 2007-05-01        2    84    52   68        51      57       -      -
# 2007-05-02        1    59    42   51        42      47    0447   1850
# 2007-05-02        2    60    43   52        42      47       -      -
# 2007-05-03        1    66    46   56        40      48    0446   1851
# 2007-05-03        2    67    48   58        40      50       -      -
#
#            PrecipTotal StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# Date
# 2007-05-01        0.00       29.10    29.82          1.7         27      9.2
# 2007-05-01        0.00       29.10    29.82          2.7         25      9.6
# 2007-05-02        0.00       29.38    30.09         13.0          4     13.4
# 2007-05-02        0.00       29.38    30.08         13.3          2     13.4
# 2007-05-03        0.00       29.39    30.12         11.7          7     11.9
# 2007-05-03        0.00       29.39    30.12         12.9          6     13.2

# %%
ind_dash = weather[weather['Sunrise']=='-'].index
# 2014-10-22        0.00       29.56    30.30          2.9          8      4.8
# 2014-10-22        0.00       29.56    30.30          3.0         11      5.1
# 2014-10-23        0.00       29.39    30.15          7.5         19      7.8
# 2014-10-23        0.00       29.39    30.16          7.9         19      8.4
# 2014-10-24        0.00       29.25    30.00          4.4         22      5.8
# 2014-10-24        0.00       29.25    30.00          4.9         22      5.8
# 2014-10-25        0.00       29.21    29.93         10.4         29     10.9
# 2014-10-25        0.00       29.21    29.92          9.7         28     10.4
# 2014-10-26        0.00       29.21    29.95          0.9          5      5.8
# 2014-10-26        0.00       29.21    29.95          1.6         11      5.4
# 2014-10-27        0.00       28.92    29.66         12.0         19     12.9
# 2014-10-27        0.00       28.92    29.67         12.7         19     13.6
# 2014-10-28       0.005       29.15    29.85         14.8         26     15.6
# 2014-10-28       0.005       29.15    29.85         14.0         26     14.6
# 2014-10-29        0.00       29.36    30.06          9.5         29      9.9
# 2014-10-29        0.00       29.36    30.07          8.5         29      9.0
# 2014-10-30        0.00       29.34    30.09          5.1         24      5.5
# 2014-10-30        0.00       29.34    30.10          5.9         23      6.5
# 2014-10-31        0.03       29.49    30.20         22.6         34     22.9
# 2014-10-31        0.03       29.49    30.20         21.7         34     22.6
#
# [2901 rows x 14 columns]

# %%
weather.loc['2009-06-18', :] 
#Checking to make sure that there aren't any other data points for the dates listed above.
# Out:
# Station            2
# Tmax              81
# Tmin              63
# Tavg              72
# DewPoint          64
# WetBulb           67
# Sunrise            -
# Sunset             -
# PrecipTotal     0.11
# StnPressure    29.15
# SeaLevel       29.79
# ResultSpeed      3.7
# ResultDir         17
# AvgSpeed         5.8
# Name: 2009-06-18 00:00:00, dtype: object

# %% [markdown]
# There are only 7, Tom G is okay with dropping them

# %%
print(weather.shape[0]-len(ind_dash))
# Out:
# 1464

# %%
weather.drop(index=ind_dash).shape
# Out:
# (17, 14)

# %%
weather.drop(index=ind_dash, inplace=True)

# %% [markdown]
# ## Setting the columns to their correct types

# %%
train.dtypes
# Out:
# Address                    object
# Species                    object
# Block                       int64
# Street                     object
# Trap                       object
# AddressNumberAndStreet     object
# Latitude                  float64
# Longitude                 float64
# AddressAccuracy             int64
# NumMosquitos                int64
# WnvPresent                  int64
# PercentageWnv             float64
# dtype: object

# %%
train.head(1) # These dtypes look right
# Out:
#                                                       Address  \
# Date
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                            Species  Block           Street  Trap  \
# Date
# 2007-05-29  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
#
#                        AddressNumberAndStreet  Latitude  Longitude  \
# Date
# 2007-05-29  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991
#
#             AddressAccuracy  NumMosquitos  WnvPresent  PercentageWnv
# Date
# 2007-05-29                9             1           0            0.0

# %%
test.dtypes #these types look right
# Out:
# Address                    object
# Species                    object
# Block                       int64
# Street                     object
# Trap                       object
# AddressNumberAndStreet     object
# Latitude                  float64
# Longitude                 float64
# AddressAccuracy             int64
# dtype: object

# %%
weather.dtypes
# Out:
# Station          int64
# Tmax             int64
# Tmin             int64
# Tavg            object
# DewPoint         int64
# WetBulb         object
# Sunrise         object
# Sunset          object
# PrecipTotal     object
# StnPressure     object
# SeaLevel        object
# ResultSpeed    float64
# ResultDir        int64
# AvgSpeed        object
# dtype: object

# %%
weather.head()
# Out:
#             Station  Tmax  Tmin Tavg  DewPoint WetBulb Sunrise Sunset  \
# Date
# 2007-05-04        1    66    49   58        41      50    0444   1852
# 2007-06-13        1    87    60   74        53      62    0416   1927
# 2007-06-28        1    74    58   66        55      60    0419   1931
# 2007-06-29        1    70    56   63        55      59    0419   1931
# 2008-07-08        1    85    70   78        67      71    0424   1929
#
#            PrecipTotal StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# Date
# 2007-05-04       0.005       29.31    30.05         10.4          8     10.8
# 2007-06-13        0.00       29.36    30.09          7.2          5      8.6
# 2007-06-28        0.00       29.41    30.09         11.9          3     12.5
# 2007-06-29        0.00       29.41    30.13          7.6          2      8.3
# 2008-07-08        0.03       29.10    29.81          7.8         26      9.1

# %%
objs = []
for col in weather.columns:
    if weather[col].dtypes == 'O':
        objs.append(col)
        
weather[objs].dtypes
# Out:
# Tavg           object
# WetBulb        object
# Sunrise        object
# Sunset         object
# PrecipTotal    object
# StnPressure    object
# SeaLevel       object
# AvgSpeed       object
# dtype: object

# %%
floats = ['PrecipTotal', 'StnPressure', 'SeaLevel', 'AvgSpeed']
ints = objs[0:6]
weather[floats] = weather[floats].astype(float)
weather[ints] = weather[ints].astype(int)
#print(floats)
#print(ints)

# %%
weather.dtypes
# Out:
# Station          int64
# Tmax             int64
# Tmin             int64
# Tavg             int64
# DewPoint         int64
# WetBulb          int64
# Sunrise          int64
# Sunset           int64
# PrecipTotal      int64
# StnPressure      int64
# SeaLevel       float64
# ResultSpeed    float64
# ResultDir        int64
# AvgSpeed       float64
# dtype: object

# %% [markdown]
# Spray

# %%
spray.dtypes
# Out:
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
test.isnull().sum().sum()
# Out:
# 0

# %%
train.isnull().sum().sum()
# Out:
# 0

# %%
weather.isnull().sum().sum()
# Out:
# 0

# %%
spray.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Splitting up the two weather stations just in case we want to use them individually later

# %%
weather_station_1 = weather.loc[weather['Station'] == 1]
weather_station_2 = weather.loc[weather['Station'] == 2]

# %%
weather_station_1.shape[0] + weather_station_2.shape[0] == weather.shape[0]
# Out:
# True

# %% [markdown]
# ## Save
# Save the cleaned files as new csvs to use in other notebooks.

# %%
train.to_csv('./assets/train_cleaned.csv')
test.to_csv('./assets/test_cleaned.csv')
spray.to_csv('./assets/spray_cleaned.csv')
weather.to_csv('./assets/weather_cleaned.csv')
weather_station_1.to_csv('./assets/weather_station_1_cleaned.csv')
weather_station_2.to_csv('./assets/weather_station_2_cleaned.csv')

# %%
# credit to Kaggle user khyh00 for the source code - https://www.kaggle.com/khyh00/west-nile-heatmap/code

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
#%matplotlib inline

from sklearn.neighbors import KernelDensity

mapdata = np.loadtxt("./assets/mapdata_copyright_openstreetmap_contributors.txt")
traps = pd.read_csv('./assets/train.csv')[['Date', 'Trap','Longitude', 'Latitude', 'WnvPresent']]

# Meaning of the colormap._lut list in matplotlib.color
# http://stackoverflow.com/questions/18035411/meaning-of-the-colormap-lut-list-in-matplotlib-color

alpha_cm = plt.cm.Greens
alpha_cm._init()
alpha_cm._lut[:-3,-1] = abs(np.logspace(0, 1, alpha_cm.N) / 10 - 1)[::-1]


aspect = mapdata.shape[0] * 1.0 / mapdata.shape[1]
lon_lat_box = (-88, -87.5, 41.6, 42.1) # xmin, xmax, ymin, ymax

sigthings = traps[traps['WnvPresent'] > 0]
sigthings = sigthings.groupby(['Date', 'Trap','Longitude', 'Latitude']).max()['WnvPresent'].reset_index()
X = sigthings[['Longitude', 'Latitude']].values
kd = KernelDensity(bandwidth=0.02)
kd.fit(X)

xv,yv = np.meshgrid(np.linspace(-88, -87.5, 100), np.linspace(41.6, 42.1, 100))
gridpoints = np.array([xv.ravel(),yv.ravel()]).T
zv = np.exp(kd.score_samples(gridpoints).reshape(100,100))
plt.figure(figsize=(10,14))
plt.imshow(mapdata, 
           cmap=plt.get_cmap('gray'), 
           extent=lon_lat_box, 
           aspect=aspect)
plt.imshow(zv, 
           origin='lower', 
           cmap=alpha_cm, 
           extent=lon_lat_box, 
           aspect=aspect)
plt.title('West Nile Heatmap')
# -> how to use 'extent' in matplotlib.pyplot.imshow
# http://stackoverflow.com/questions/6999621/how-to-use-extent-in-matplotlib-pyplot-imshow

locations = traps[['Longitude', 'Latitude']].drop_duplicates().values
plt.scatter(locations[:,0], locations[:,1], marker='*', color = 'b')

plt.savefig('heatmap.png')

# %%
from sklearn.cluster import DBSCAN, KMeans
 
spray = pd.read_csv('./assets/spray.csv')
train = pd.read_csv('./assets/train.csv')

X_spray = spray[['Latitude', 'Longitude']] 
spray_cluster_model = DBSCAN(eps=.01, min_samples=25).fit(X_spray)
X_spray['cluster'] = spray_cluster_model.labels_  

spray_lon_lat_box = (X_spray['Longitude'].min()-.1, X_spray['Longitude'].max()+.1, X_spray['Latitude'].min()-.1,X_spray['Latitude'].max()+.1)

fig, ax = plt.subplots(figsize=(10,14))
ax.imshow(mapdata, cmap=plt.get_cmap('gray'), aspect='auto', extent=spray_lon_lat_box) 

for i in X_spray['cluster'].unique():  
    ax.scatter(X_spray[X_spray['cluster'] == i]['Longitude'], 
               X_spray[X_spray['cluster'] == i]['Latitude'], 
               label=i, marker='o')

plt.scatter(train[train['WnvPresent'] == 1]['Longitude'], 
            train[train['WnvPresent'] == 1]['Latitude'], 
            marker='*', label='WNV Present', color='b')
plt.legend()
plt.title('Spray Clusters', size=15);
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import seaborn as sns
sns.distplot(train.NumMosquitos)
plt.show()

# %%
# Check how many unique values there are for Species
print(train["Species"].unique())
# Out:
# WnvPresent value counts: 0    9955
# 1     551
# Name: WnvPresent, dtype: int64
# ['CULEX PIPIENS/RESTUANS' 'CULEX RESTUANS' 'CULEX PIPIENS'
#  'CULEX SALINARIUS' 'CULEX TERRITANS' 'CULEX TARSALIS' 'CULEX ERRATICUS']

# %%
# Check the distribution of our target variable
train.WnvPresent.value_counts()
# Out:
# 0    9955
# 1     551
# Name: WnvPresent, dtype: int64

# %%
# Look at the distributions of numeric columns
sns.distplot(train.AddressAccuracy)
plt.show()
train.AddressAccuracy.value_counts()
# Out:
# 8    4628
# 9    3980
# 5    1807
# 3      91
# Name: AddressAccuracy, dtype: int64
